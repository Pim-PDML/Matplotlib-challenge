# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import random

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
#294
mouse_metadata = pd.read_csv(mouse_metadata_path)
#1893
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
#1893
mouse_study = pd.merge(mouse_metadata, study_results, on="Mouse ID")

# Display the data table for preview
mouse_study.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice.
#249
len(mouse_study["Mouse ID"].unique())
#mouse_study.loc[(mouse_study["Mouse ID"] =="g989"),:]
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
#mouse_study["Mouse ID"].value_counts()
#mouse_study.loc[(mouse_study["Mouse ID"] =="g989"),:]

dup_mouse_g = mouse_study.groupby(['Mouse ID','Timepoint'])
dup_mouse = dup_mouse_g.count()

del dup_mouse["Sex"]
del dup_mouse["Age_months"]
del dup_mouse["Weight (g)"]
del dup_mouse["Tumor Volume (mm3)"]
del dup_mouse["Metastatic Sites"]

dup_mouse = dup_mouse.rename(columns={"Drug Regimen":"duplicate_count"})
#g989
dup_mouse.loc[(dup_mouse["duplicate_count"] > 1),:]

#13
mouse_study.loc[(mouse_study["Mouse ID"] =="g989"),:]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Optional: Get all the data for the duplicate mouse ID. 
dup_mouse_g989 = mouse_study.loc[(mouse_study["Mouse ID"] =="g989"),:]
dup_mouse_g989
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
#1880
mouse_study_nodup  = mouse_study.loc[(mouse_study["Mouse ID"] !="g989"),:]
mouse_study_nodup.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
#248
len(mouse_study_nodup["Mouse ID"].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

tumor_regimen_g = mouse_study_nodup.groupby(['Drug Regimen'])
mean = tumor_regimen_g['Tumor Volume (mm3)'].mean()
median = tumor_regimen_g['Tumor Volume (mm3)'].median()
variance = tumor_regimen_g['Tumor Volume (mm3)'].var()
std = tumor_regimen_g['Tumor Volume (mm3)'].std()
sem = tumor_regimen_g['Tumor Volume (mm3)'].sem()

# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary = pd.merge(mean, median, on="Drug Regimen")
summary = summary.rename(columns={"Tumor Volume (mm3)_x":"mean"})
summary = summary.rename(columns={"Tumor Volume (mm3)_y":"median"})
summary = pd.merge(summary, variance, on="Drug Regimen")
summary = summary.rename(columns={"Tumor Volume (mm3)":"variance"})
summary = pd.merge(summary, std, on="Drug Regimen")
summary = summary.rename(columns={"Tumor Volume (mm3)":"standard deviation"})
summary = pd.merge(summary, sem, on="Drug Regimen")
summary = summary.rename(columns={"Tumor Volume (mm3)":"SEM"})

summary

# Using the aggregation method, produce the same summary statistics in a single line


# alternative_df = pd.merge(bitcoin_df, dash_df, on= "Date", suffixes= ("_Bitcoin", "_Dash"))
# alternative_df.head()
# Out:
#                    mean     median   variance  standard deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# mice_drug_time_g = mouse_study_nodup.groupby(['Mouse ID','Drug Regimen'])
# mice_drug_time = mice_drug_time_g['Timepoint'].sum()
# #pd.set_option('display.max_rows', None)
# mice_drug_time = mice_drug_time.reset_index()
# sample = mice_drug_time.head(50)

# multi_plot = sample.plot(kind="bar", figsize=(20,5))

mice_drug_time_g = mouse_study_nodup.groupby(['Drug Regimen'])
mice_drug_time = mice_drug_time_g['Timepoint'].sum()
#pd.set_option('display.max_rows', None)
mice_drug_time = mice_drug_time.reset_index()
#sample = mice_drug_time.head(50)

#Pandas 
x_axis = np.arange(len(mice_drug_time))
tick_locations = [value+0.4 for value in x_axis]

mice_drug_time.plot(kind ="bar", figsize=(18,3))
plt.xticks(tick_locations, ["Capomulin","Ceftamin","Infubinol","Ketapril","Naftisol","Placebo","Propriva","Ramicane","Stelasyn","Zoniferol"])
plt.show()



# multi_plot = mice_drug_time.plot(kind="bar", figsize=(20,5))

# plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
#multi_plot.set_xticklabels(sample["Mouse ID"], rotation=45)

#plt.tight_layout()

# plt.hist(multi_plot)
# plt.show()
# print(st.normaltest(multi_plot.sample(50)))

#mice_drug_time.loc[(mice_drug_time["Mouse ID"] =="x773"),:]

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

#Matplotlob
plt.figure(figsize=(20,3))
plt.bar(x_axis, mice_drug_time["Timepoint"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, mice_drug_time["Drug Regimen"], rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x18f4d9b9550>,
# ...
#  [Text(0.4, 0, 'Capomulin'),
#   Text(1.4, 0, 'Ceftamin'),
#   Text(2.4, 0, 'Infubinol'),
#   Text(3.4, 0, 'Ketapril'),
#   Text(4.4, 0, 'Naftisol'),
#   Text(5.4, 0, 'Placebo'),
#   Text(6.4, 0, 'Propriva'),
#   Text(7.4, 0, 'Ramicane'),
#   Text(8.4, 0, 'Stelasyn'),
#   Text(9.4, 0, 'Zoniferol')])

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

sex_g = mouse_study_nodup.groupby(['Sex','Mouse ID'])
sex = sex_g.count()
sex = sex.reset_index()

del sex["Drug Regimen"]
del sex["Age_months"]
del sex["Weight (g)"]
del sex["Timepoint"]
del sex["Tumor Volume (mm3)"]
del sex["Metastatic Sites"]

sex_g = sex.groupby(['Sex'])
sex = sex_g.count()
sex = sex.reset_index()

sex

#pandas plot pie
sex.plot(kind='pie', y='Mouse ID', autopct='%1.1f%%', colors = ['red', 'lightskyblue'], labels = sex['Sex'])
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

sex

# The colors of each section of the pie chart
colors = ["red", "lightskyblue"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0, 0)

plt.pie(sex['Mouse ID'], explode=explode, labels=sex['Sex'], colors=colors, autopct="%1.1f%%", shadow=True, startangle=180)
# Create axes which are equal so we have a perfect circle
plt.axis("equal")
# Out:
# (-1.1001516367431872,
#  1.103184371606931,
#  -1.103492681505578,
#  1.1018390827045563)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
tumor_g = mouse_study_nodup.groupby(['Mouse ID'])
tumor_mx = tumor_g['Timepoint'].max()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
summary = pd.merge(tumor_mx, mouse_study_nodup, on=["Mouse ID","Timepoint"])
summary

#summary['Drug Regimen'].unique()
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
x_axis = np.arange(len(summary))
tick_locations = [value+0.4 for value in x_axis]

# plt.xticks(tick_locations, ["Capomulin","Ceftamin","Infubinol","Ketapril","Naftisol","Placebo","Propriva","Ramicane","Stelasyn","Zoniferol"])
# plt.show()

# Create empty list to fill with tumor vol data (for plotting)
tumor = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

#If the data is in a dataframe, we use pandas to give quartile calculations

total = summary[['Mouse ID','Tumor Volume (mm3)']]


fig1, ax1  = plt.subplots()
ax1.boxplot(total)
plt.show()

quartiles = total.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of Tumor Volume is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1d11195fb941> in <module>
#      17
#      18 fig1, ax1  = plt.subplots()
# ---> 19 ax1.boxplot(total)
#      20 plt.show()
#      21
#
# D:\Program\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\Program\lib\site-packages\matplotlib\axes\_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
mouse_study_nodup
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin = mouse_study_nodup.loc[(mouse_study_nodup["Drug Regimen"] =="Capomulin"),:]
capomulin = capomulin.loc[(mouse_study_nodup["Mouse ID"] =="s185"),:]
capomulin

# Set x axis to numerical value for month
x_axis_data = np.arange(0,50,5)
x_axis_data
# Average weather temp
tumor = capomulin['Tumor Volume (mm3)']

# Give our graph axis labels
plt.title("tumor volume vs. time point for s185")
plt.xlabel("Timepoint")
plt.ylabel("Tumor Volume (mm3)")


plt.plot(x_axis_data, tumor)
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

capomulin_g = mouse_study_nodup.loc[(mouse_study_nodup["Drug Regimen"] =="Capomulin"),:]

Capomulin_w = capomulin_g.groupby(['Mouse ID','Weight (g)'])
Capomulin_avg = Capomulin_w['Tumor Volume (mm3)'].mean()

Capomulin_avg = Capomulin_avg.reset_index()
Capomulin_avg

# The maximum x value for our chart will be 100
#_limit = 26

# List of values from 0 to 100 each value being 1 greater than the last
#_axis = np.arange(15, x_limit, 1)

# Create a random array of data that we will use for our y values
data = [random.random() for value in x_axis]
x =Capomulin_avg['Weight (g)']
y =Capomulin_avg['Tumor Volume (mm3)']

plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")

# Tells matplotlib that we want to make a scatter plot
# The size of each point on our plot is determined by their x value
plt.scatter(x,y, marker="o", facecolors="red", edgecolors="black",
            s=x, alpha=0.75)

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

plt.scatter(Capomulin_avg.iloc[:,1],Capomulin_avg.iloc[:,2])
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
#description of observable trends
#-The longer the time The dosage of the drug is even lower.
#-Capomulin and Stelasyn last longer than other drugs.
#-The weight of the rats and the dose of the drug were correlation.

mice_drug_time
# Out:
#   Drug Regimen  Timepoint
# 0    Capomulin       4960
# 1     Ceftamin       3515
# 2    Infubinol       3235
# 3     Ketapril       3705
# 4     Naftisol       3650
# 5      Placebo       3380
# 6     Propriva       2525
# 7     Ramicane       4885
# 8     Stelasyn       3480
# 9    Zoniferol       3525
